# %% [markdown]
# ## Optuna

# %% [markdown]
# To optimize our hyperparameters we use Optuna which is an automatic hyperparameter optimization software framework that uses Bayesian Optimization.

# %% [markdown]
# Each parameter to search over should have a value of the following format: `'parameter_name': ('type', lower_bound, upper_bound)`
#
# `'type'` can have one of 4 values:
# - `'int'`: search over integers in the interval **[lower_bound, upper_bound]** (uniform distribution)
# - `'int-log'`: search over powers of 2 in the interval **[2^lower_bound, 2^upper_bound]** (uniform distribution)
# - `'float'`: search over floating-point numbers in the interval **[lower_bound, upper_bound]** with each number having the same probability to be sampled (uniform distribution)
# - `'float-log'`: search over floating-point numbers in the interval **[lower_bound, upper_bound]** with smaller values having a higher probability to be sampled (uniform distribution in log domain)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.optuna import create_optuna_objective
from src.dataset import get_imagenet_info, get_tiny_imagenet_info

# %% [markdown]
# ### Pretext

# %% [markdown]
# This is an example of the optuna_pretext_script running on a small subset of the ImageNet dataset for only 2 epochs for demonstration purposes

# %% [markdown]
# This is an example of the optuna_downstream_script running on a small subset of the Tiny ImageNet dataset for only 2 epochs for demonstration purposes.
# In this example we would search over the following parameters:
# - `optimizer_kwargs.lr`: logarithmically sample in the interval [1e-5, 1e-3]

# %%
imagenet_info = get_imagenet_info()

# %%
import optuna
from torchvision.transforms import Compose, RandomResizedCrop, RandomGrayscale, GaussianBlur, ColorJitter, RandomSolarize

from src.optuna import create_optuna_objective

aug_transform = Compose([
    RandomResizedCrop(size=224, scale=(0.32, 1.0), ratio=(0.75, 1.3333333333333333)),
    ColorJitter(brightness=0.8, contrast=0.8, saturation=0.8, hue=0.2),
    RandomGrayscale(p=0.05),
    GaussianBlur(kernel_size=23, sigma=(1e-10, 0.2)),
    RandomSolarize(0.7, p=0.2),
])

RUN_PRETEXT_PARAMS = {
    "experiment_id": "optuna_test",
    "pretext_type": "our",
    "aug_transform": aug_transform,
    "loss_alpha": 1,
    "loss_symmetric": True,
    "optimizer_kwargs": {
        "lr": ("float-log", 1e-5, 1e-3),
        "weight_decay": 0,
    },
    "batch_size": 64,
    "num_workers": 0,
    "log_frequency": 100,
    "cache_images": True,
    "resume_from_checkpoint": False,
    "imagenet_info": imagenet_info[:100],
    "n_train": 90,
    "num_epochs": 2,
}

# maximal number of trials to perform
N_TRIALS = 10
# stops search if last trial ended more than TIMEOUT seconds after the start
TIMEOUT = 300

# create objective function
objective = create_optuna_objective(RUN_PRETEXT_PARAMS, save_models=False)

# create study
study = optuna.create_study(direction="maximize")

# run study
study.optimize(objective, n_trials=N_TRIALS, timeout=TIMEOUT)
# Out:
# [I 2022-12-13 12:34:20,454] A new study created in memory with name: no-name-099c443d-b9e7-4400-93d4-6ae7565c0ac6
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-34-20                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 0.0002503179772396286, 'weight_decay': 0}                                                                                                    |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 11.815s (11.815s)	Speed 5.4 samples/s	Loss 4.18322 (4.18322)
# Epoch: [0][1/1]	Time 4.943s (8.379s)	Speed 5.3 samples/s	Loss 4.84185 (4.37349)
# Test: [0/0]	Time 0.464 (0.464)	Loss 4.1640 (4.1640)
# Accuracy: 0.000
# Epoch: [1][0/1]	Time 11.810s (11.810s)	Speed 5.4 samples/s	Loss 4.66117 (4.66117)
# Epoch: [1][1/1]	Time 4.955s (8.382s)	Speed 5.2 samples/s	Loss 3.95330 (4.45667)
# Test: [0/0]	Time 0.463 (0.463)	Loss 4.1091 (4.1091)
# Accuracy: 0.200
# [I 2022-12-13 12:35:06,625] Trial 0 finished with value: 0.2 and parameters: {'lr': 0.0002503179772396286}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-35-06                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 1.2757404722759047e-05, 'weight_decay': 0}                                                                                                   |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 11.627s (11.627s)	Speed 5.5 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 5.011s (8.319s)	Speed 5.2 samples/s	Loss 4.14833 (4.16094)
# Test: [0/0]	Time 0.461 (0.461)	Loss 4.1767 (4.1767)
# Accuracy: 0.100
# Epoch: [1][0/1]	Time 11.781s (11.781s)	Speed 5.4 samples/s	Loss 4.14792 (4.14792)
# Epoch: [1][1/1]	Time 4.977s (8.379s)	Speed 5.2 samples/s	Loss 4.08186 (4.12884)
# Test: [0/0]	Time 0.467 (0.467)	Loss 4.1909 (4.1909)
# Accuracy: 0.000
# [I 2022-12-13 12:35:52,668] Trial 1 finished with value: 0.1 and parameters: {'lr': 1.2757404722759047e-05}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-35-52                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 0.0005400389391690477, 'weight_decay': 0}                                                                                                    |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 11.815s (11.815s)	Speed 5.4 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 4.966s (8.390s)	Speed 5.2 samples/s	Loss 6.91832 (4.96116)
# Test: [0/0]	Time 0.478 (0.478)	Loss 4.2980 (4.2980)
# Accuracy: 0.000
# Epoch: [1][0/1]	Time 12.032s (12.032s)	Speed 5.3 samples/s	Loss 5.54742 (5.54742)
# Epoch: [1][1/1]	Time 4.965s (8.498s)	Speed 5.2 samples/s	Loss 4.15757 (5.14591)
# Test: [0/0]	Time 0.461 (0.461)	Loss 4.3163 (4.3163)
# Accuracy: 0.200
# [I 2022-12-13 12:36:39,537] Trial 2 finished with value: 0.2 and parameters: {'lr': 0.0005400389391690477}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-36-39                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 3.265815172616971e-05, 'weight_decay': 0}                                                                                                    |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 12.004s (12.004s)	Speed 5.3 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 5.037s (8.520s)	Speed 5.2 samples/s	Loss 4.14132 (4.15892)
# Test: [0/0]	Time 0.478 (0.478)	Loss 4.1651 (4.1651)
# Accuracy: 0.100
# Epoch: [1][0/1]	Time 11.864s (11.864s)	Speed 5.4 samples/s	Loss 4.12783 (4.12783)
# Epoch: [1][1/1]	Time 4.963s (8.414s)	Speed 5.2 samples/s	Loss 4.00845 (4.09334)
# Test: [0/0]	Time 0.481 (0.481)	Loss 4.1518 (4.1518)
# Accuracy: 0.050
# [I 2022-12-13 12:37:26,459] Trial 3 finished with value: 0.1 and parameters: {'lr': 3.265815172616971e-05}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-37-26                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 0.00010746504848533198, 'weight_decay': 0}                                                                                                   |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 12.121s (12.121s)	Speed 5.3 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 5.179s (8.650s)	Speed 5.0 samples/s	Loss 4.26172 (4.19370)
# Test: [0/0]	Time 0.467 (0.467)	Loss 4.1472 (4.1472)
# Accuracy: 0.000
# Epoch: [1][0/1]	Time 11.822s (11.822s)	Speed 5.4 samples/s	Loss 4.24741 (4.24741)
# Epoch: [1][1/1]	Time 5.000s (8.411s)	Speed 5.2 samples/s	Loss 3.93606 (4.15746)
# Test: [0/0]	Time 0.463 (0.463)	Loss 4.1157 (4.1157)
# Accuracy: 0.200
# [I 2022-12-13 12:38:13,783] Trial 4 finished with value: 0.2 and parameters: {'lr': 0.00010746504848533198}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-38-13                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 0.0008344876186784779, 'weight_decay': 0}                                                                                                    |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 11.688s (11.688s)	Speed 5.5 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 5.001s (8.344s)	Speed 5.2 samples/s	Loss 9.55866 (5.72393)
# Test: [0/0]	Time 0.471 (0.471)	Loss 5.7000 (5.7000)
# Accuracy: 0.000
# Epoch: [1][0/1]	Time 11.846s (11.846s)	Speed 5.4 samples/s	Loss 6.42229 (6.42229)
# Epoch: [1][1/1]	Time 4.999s (8.422s)	Speed 5.2 samples/s	Loss 4.40748 (5.84023)
# Test: [0/0]	Time 0.462 (0.462)	Loss 23.7474 (23.7474)
# Accuracy: 0.200
# [I 2022-12-13 12:39:00,073] Trial 5 finished with value: 0.2 and parameters: {'lr': 0.0008344876186784779}. Best is trial 0 with value: 0.2.
# | parameter              | value                                                                                                                                               |
# |:-----------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------|
# | experiment_id          | optuna_test_2022-12-13_12-39-00                                                                                                                     |
# | aug_transform          | Compose(                                                                                                                                            |
# |                        |     RandomResizedCrop(size=(224, 224), scale=(0.32, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear), antialias=None)                            |
# |                        |     ColorJitter(brightness=[0.19999999999999996, 1.8], contrast=[0.19999999999999996, 1.8], saturation=[0.19999999999999996, 1.8], hue=[-0.2, 0.2]) |
# |                        |     RandomGrayscale(p=0.05)                                                                                                                         |
# |                        |     GaussianBlur(kernel_size=(23, 23), sigma=(1e-10, 0.2))                                                                                          |
# |                        |     RandomSolarize(threshold=0.7,p=0.2)                                                                                                             |
# |                        | )                                                                                                                                                   |
# | pretext_type           | our                                                                                                                                                 |
# | loss_alpha             | 1                                                                                                                                                   |
# | loss_symmetric         | True                                                                                                                                                |
# | n_train                | 90                                                                                                                                                  |
# | optimizer_kwargs       | {'lr': 6.363183345999709e-05, 'weight_decay': 0}                                                                                                    |
# | num_epochs             | 2                                                                                                                                                   |
# | batch_size             | 64                                                                                                                                                  |
# | num_workers            | 0                                                                                                                                                   |
# | log_frequency          | 100                                                                                                                                                 |
# | cache_images           | True                                                                                                                                                |
# | resume_from_checkpoint | False                                                                                                                                               |
# | save_models            | False                                                                                                                                               |
# | logger                 | <RootLogger root (INFO)>                                                                                                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 11.744s (11.744s)	Speed 5.4 samples/s	Loss 4.16607 (4.16607)
# Epoch: [0][1/1]	Time 5.040s (8.392s)	Speed 5.2 samples/s	Loss 4.16499 (4.16576)
# Test: [0/0]	Time 0.464 (0.464)	Loss 4.1546 (4.1546)
# Accuracy: 0.050
# Epoch: [1][0/1]	Time 12.024s (12.024s)	Speed 5.3 samples/s	Loss 4.15554 (4.15554)
# Epoch: [1][1/1]	Time 5.118s (8.571s)	Speed 5.1 samples/s	Loss 3.96050 (4.09920)
# Test: [0/0]	Time 0.467 (0.467)	Loss 4.1159 (4.1159)
# Accuracy: 0.200
# [I 2022-12-13 12:39:47,182] Trial 6 finished with value: 0.2 and parameters: {'lr': 6.363183345999709e-05}. Best is trial 0 with value: 0.2.

# %% [markdown]
# ### Downstream

# %% [markdown]
# This is an example of the optuna_downstream_script running on a small subset of the Tiny ImageNet dataset for only 2 epochs for demonstration purposes.
# In this example we would search over the following parameters:
# - `use_aug_transform`: uniformly sample either 0 (False) or 1 (True)
# - `optimizer_kwargs.lr`: logarithmically sample in the interval [1e-5, 1e-3]
# - `optimizer_kwargs.lr`: logarithmically sample in the interval [1e-7, 1e-3]
# - `batch_size`: uniformly sample an integer in the interval [5, 8] and set to 2^[sampled_int]

# %%
tiny_imagenet_info = get_tiny_imagenet_info()

# %%
import optuna
from src.utils import load_best_model
from src.models import OurPretextNetwork
from src.optuna import create_optuna_objective

# specify experiment id to load pretext model from
PRETEXT_EXPERIMENT_ID = "dustin_lr_5e5"

# load pretext model
pretext_model = load_best_model(PRETEXT_EXPERIMENT_ID, OurPretextNetwork(backbone="resnet18"))

RUN_DOWNSTREAM_PARAMS = {
    "experiment_id": "optuna_downstream_test",
    "pretext_model": pretext_model,
    "use_aug_transform": ("int", 0, 1),
    "optimizer_kwargs": {
        "lr": ("float-log", 1e-5, 1e-3),
        "weight_decay": ("float-log", 1e-7, 1e-3),
    },
    "batch_size": ("int-log", 5, 8),
    "n_train": 9000,
    "cache_images": True,
    "num_workers": 0,
    "tiny_imagenet_info": tiny_imagenet_info[:100],
    "n_train": 90,
    "num_epochs": 2,
}

# maximal number of trials to perform
N_TRIALS = 10
# stops search if last trial ended more than TIMEOUT seconds after the start
TIMEOUT = 300

# create objective function
objective = create_optuna_objective(RUN_DOWNSTREAM_PARAMS, save_models=False)

# create study
study = optuna.create_study(direction="maximize")

# run study
study.optimize(objective, n_trials=N_TRIALS, timeout=TIMEOUT)
# Out:
# [I 2022-12-13 12:39:47,470] A new study created in memory with name: no-name-fd4d1b30-03ab-4554-a1dc-6b62f52bb511
# | parameter              | value                                                                 |
# |:-----------------------|:----------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-39-47                            |
# | use_aug_transform      | 1                                                                     |
# | n_train                | 90                                                                    |
# | optimizer_kwargs       | {'lr': 0.00033736263398492994, 'weight_decay': 1.760927885804667e-07} |
# | num_epochs             | 2                                                                     |
# | batch_size             | 128                                                                   |
# | num_workers            | 0                                                                     |
# | log_frequency          | 100                                                                   |
# | cache_images           | True                                                                  |
# | resume_from_checkpoint | False                                                                 |
# | save_models            | False                                                                 |
# | logger                 | <RootLogger root (INFO)>                                              |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.639s (2.639s)	Speed 34.1 samples/s	Loss 5.29468 (5.29468)
# Test: [0/0]	Time 0.155 (0.155)	Loss 5.2275 (5.2275)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.499s (2.499s)	Speed 36.0 samples/s	Loss 5.13466 (5.13466)
# Test: [0/0]	Time 0.179 (0.179)	Loss 5.2169 (5.2169)
# Accuracy: 0.000
# [I 2022-12-13 12:39:53,242] Trial 0 finished with value: 0.0 and parameters: {'use_aug_transform': 1, 'lr': 0.00033736263398492994, 'weight_decay': 1.760927885804667e-07, 'batch_size': 7}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-39-53                           |
# | use_aug_transform      | 1                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 0.00021019073131369996, 'weight_decay': 6.62478009342218e-05} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 256                                                                  |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.500s (2.500s)	Speed 36.0 samples/s	Loss 5.29415 (5.29415)
# Test: [0/0]	Time 0.158 (0.158)	Loss 5.3091 (5.3091)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.435s (2.435s)	Speed 37.0 samples/s	Loss 5.18979 (5.18979)
# Test: [0/0]	Time 0.155 (0.155)	Loss 5.2700 (5.2700)
# Accuracy: 0.000
# [I 2022-12-13 12:39:58,766] Trial 1 finished with value: 0.0 and parameters: {'use_aug_transform': 1, 'lr': 0.00021019073131369996, 'weight_decay': 6.62478009342218e-05, 'batch_size': 8}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-39-58                           |
# | use_aug_transform      | 1                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 5.984359464826345e-05, 'weight_decay': 2.394504341061989e-06} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 128                                                                  |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.482s (2.482s)	Speed 36.3 samples/s	Loss 5.29415 (5.29415)
# Test: [0/0]	Time 0.158 (0.158)	Loss 5.3285 (5.3285)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.501s (2.501s)	Speed 36.0 samples/s	Loss 5.26832 (5.26832)
# Test: [0/0]	Time 0.153 (0.153)	Loss 5.3102 (5.3102)
# Accuracy: 0.000
# [I 2022-12-13 12:40:04,412] Trial 2 finished with value: 0.0 and parameters: {'use_aug_transform': 1, 'lr': 5.984359464826345e-05, 'weight_decay': 2.394504341061989e-06, 'batch_size': 7}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-04                           |
# | use_aug_transform      | 0                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 0.0001202207819391489, 'weight_decay': 1.956518971455907e-05} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 128                                                                  |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.566s (2.566s)	Speed 35.1 samples/s	Loss 5.29826 (5.29826)
# Test: [0/0]	Time 0.154 (0.154)	Loss 5.3058 (5.3058)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.493s (2.493s)	Speed 36.1 samples/s	Loss 5.20896 (5.20896)
# Test: [0/0]	Time 0.170 (0.170)	Loss 5.2885 (5.2885)
# Accuracy: 0.000
# [I 2022-12-13 12:40:10,173] Trial 3 finished with value: 0.0 and parameters: {'use_aug_transform': 0, 'lr': 0.0001202207819391489, 'weight_decay': 1.956518971455907e-05, 'batch_size': 7}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-10                           |
# | use_aug_transform      | 1                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 0.00015201058567270963, 'weight_decay': 0.000248873935417907} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 128                                                                  |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.457s (2.457s)	Speed 36.6 samples/s	Loss 5.30783 (5.30783)
# Test: [0/0]	Time 0.154 (0.154)	Loss 5.3167 (5.3167)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.474s (2.474s)	Speed 36.4 samples/s	Loss 5.22985 (5.22985)
# Test: [0/0]	Time 0.176 (0.176)	Loss 5.3562 (5.3562)
# Accuracy: 0.000
# [I 2022-12-13 12:40:15,745] Trial 4 finished with value: 0.0 and parameters: {'use_aug_transform': 1, 'lr': 0.00015201058567270963, 'weight_decay': 0.000248873935417907, 'batch_size': 7}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                               |
# |:-----------------------|:--------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-15                          |
# | use_aug_transform      | 0                                                                   |
# | n_train                | 90                                                                  |
# | optimizer_kwargs       | {'lr': 0.0009033113952266668, 'weight_decay': 0.000958751435611062} |
# | num_epochs             | 2                                                                   |
# | batch_size             | 256                                                                 |
# | num_workers            | 0                                                                   |
# | log_frequency          | 100                                                                 |
# | cache_images           | True                                                                |
# | resume_from_checkpoint | False                                                               |
# | save_models            | False                                                               |
# | logger                 | <RootLogger root (INFO)>                                            |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/0]	Time 2.463s (2.463s)	Speed 36.5 samples/s	Loss 5.29826 (5.29826)
# Test: [0/0]	Time 0.155 (0.155)	Loss 5.2066 (5.2066)
# Accuracy: 0.000
# Epoch: [1][0/0]	Time 2.458s (2.458s)	Speed 36.6 samples/s	Loss 4.68936 (4.68936)
# Test: [0/0]	Time 0.159 (0.159)	Loss 5.1124 (5.1124)
# Accuracy: 0.000
# [I 2022-12-13 12:40:21,320] Trial 5 finished with value: 0.0 and parameters: {'use_aug_transform': 0, 'lr': 0.0009033113952266668, 'weight_decay': 0.000958751435611062, 'batch_size': 8}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-21                           |
# | use_aug_transform      | 0                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 5.574978073224192e-05, 'weight_decay': 3.769504795721094e-05} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 64                                                                   |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/1]	Time 1.816s (1.816s)	Speed 35.2 samples/s	Loss 5.33588 (5.33588)
# Epoch: [0][1/1]	Time 0.804s (1.310s)	Speed 32.3 samples/s	Loss 5.25808 (5.31340)
# Test: [0/0]	Time 0.159 (0.159)	Loss 5.3512 (5.3512)
# Accuracy: 0.000
# Epoch: [1][0/1]	Time 1.785s (1.785s)	Speed 35.8 samples/s	Loss 5.23838 (5.23838)
# Epoch: [1][1/1]	Time 0.804s (1.295s)	Speed 32.3 samples/s	Loss 5.24665 (5.24077)
# Test: [0/0]	Time 0.160 (0.160)	Loss 5.3435 (5.3435)
# Accuracy: 0.000
# [I 2022-12-13 12:40:27,147] Trial 6 finished with value: 0.0 and parameters: {'use_aug_transform': 0, 'lr': 5.574978073224192e-05, 'weight_decay': 3.769504795721094e-05, 'batch_size': 6}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                 |
# |:-----------------------|:----------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-27                            |
# | use_aug_transform      | 1                                                                     |
# | n_train                | 90                                                                    |
# | optimizer_kwargs       | {'lr': 7.692827934135007e-05, 'weight_decay': 1.0170548276817186e-07} |
# | num_epochs             | 2                                                                     |
# | batch_size             | 32                                                                    |
# | num_workers            | 0                                                                     |
# | log_frequency          | 100                                                                   |
# | cache_images           | True                                                                  |
# | resume_from_checkpoint | False                                                                 |
# | save_models            | False                                                                 |
# | logger                 | <RootLogger root (INFO)>                                              |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/2]	Time 0.974s (0.974s)	Speed 32.9 samples/s	Loss 5.33102 (5.33102)
# Epoch: [0][2/2]	Time 0.800s (0.912s)	Speed 32.5 samples/s	Loss 5.26040 (5.30899)
# Test: [0/0]	Time 0.158 (0.158)	Loss 5.3221 (5.3221)
# Accuracy: 0.000
# Epoch: [1][0/2]	Time 0.950s (0.950s)	Speed 33.7 samples/s	Loss 5.25152 (5.25152)
# Epoch: [1][2/2]	Time 0.789s (0.902s)	Speed 32.9 samples/s	Loss 5.17161 (5.21727)
# Test: [0/0]	Time 0.154 (0.154)	Loss 5.3602 (5.3602)
# Accuracy: 0.000
# [I 2022-12-13 12:40:33,173] Trial 7 finished with value: 0.0 and parameters: {'use_aug_transform': 1, 'lr': 7.692827934135007e-05, 'weight_decay': 1.0170548276817186e-07, 'batch_size': 5}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                |
# |:-----------------------|:---------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-33                           |
# | use_aug_transform      | 0                                                                    |
# | n_train                | 90                                                                   |
# | optimizer_kwargs       | {'lr': 0.0003889958202419417, 'weight_decay': 3.440700388623523e-05} |
# | num_epochs             | 2                                                                    |
# | batch_size             | 32                                                                   |
# | num_workers            | 0                                                                    |
# | log_frequency          | 100                                                                  |
# | cache_images           | True                                                                 |
# | resume_from_checkpoint | False                                                                |
# | save_models            | False                                                                |
# | logger                 | <RootLogger root (INFO)>                                             |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/2]	Time 0.963s (0.963s)	Speed 33.2 samples/s	Loss 5.29330 (5.29330)
# Epoch: [0][2/2]	Time 0.851s (0.940s)	Speed 30.6 samples/s	Loss 5.26947 (5.30076)
# Test: [0/0]	Time 0.175 (0.175)	Loss 5.2473 (5.2473)
# Accuracy: 0.000
# Epoch: [1][0/2]	Time 1.055s (1.055s)	Speed 30.3 samples/s	Loss 4.83935 (4.83935)
# Epoch: [1][2/2]	Time 0.787s (0.944s)	Speed 33.1 samples/s	Loss 4.53946 (4.70307)
# Test: [0/0]	Time 0.154 (0.154)	Loss 5.1702 (5.1702)
# Accuracy: 0.000
# [I 2022-12-13 12:40:39,423] Trial 8 finished with value: 0.0 and parameters: {'use_aug_transform': 0, 'lr': 0.0003889958202419417, 'weight_decay': 3.440700388623523e-05, 'batch_size': 5}. Best is trial 0 with value: 0.0.
# | parameter              | value                                                                 |
# |:-----------------------|:----------------------------------------------------------------------|
# | experiment_id          | optuna_downstream_test_2022-12-13_12-40-39                            |
# | use_aug_transform      | 0                                                                     |
# | n_train                | 90                                                                    |
# | optimizer_kwargs       | {'lr': 0.00037714503391425124, 'weight_decay': 2.804626188785637e-05} |
# | num_epochs             | 2                                                                     |
# | batch_size             | 32                                                                    |
# | num_workers            | 0                                                                     |
# | log_frequency          | 100                                                                   |
# | cache_images           | True                                                                  |
# | resume_from_checkpoint | False                                                                 |
# | save_models            | False                                                                 |
# | logger                 | <RootLogger root (INFO)>                                              |
# Device: cpu
# Number of training images: 	 90
# Number of validation images: 	 10
# Epoch: [0][0/2]	Time 0.949s (0.949s)	Speed 33.7 samples/s	Loss 5.33424 (5.33424)
# Epoch: [0][2/2]	Time 0.894s (0.935s)	Speed 29.1 samples/s	Loss 5.27845 (5.31370)
# Test: [0/0]	Time 0.176 (0.176)	Loss 5.3182 (5.3182)
# Accuracy: 0.000
# Epoch: [1][0/2]	Time 0.962s (0.962s)	Speed 33.3 samples/s	Loss 4.87679 (4.87679)
# Epoch: [1][2/2]	Time 0.820s (0.910s)	Speed 31.7 samples/s	Loss 4.58253 (4.72699)
# Test: [0/0]	Time 0.165 (0.165)	Loss 5.2730 (5.2730)
# Accuracy: 0.000
# [I 2022-12-13 12:40:45,554] Trial 9 finished with value: 0.0 and parameters: {'use_aug_transform': 0, 'lr': 0.00037714503391425124, 'weight_decay': 2.804626188785637e-05, 'batch_size': 5}. Best is trial 0 with value: 0.0.
